# %%
Task_2

# %%
# input varibles:

# %%
 younge_age 10 ----20
teen_age >20---40

# %%
my_age= 20

# %%
comparision_value=20

# %%
print("your program start")
if my_age >=comparision_value:
    print("your are teen_age")
else:
    print("your are younge_age")
print("your program ends")
# Out:
# your program start
# your are teen_age
# your program ends

# %%
my_age=30

# %%
comparision_value=20

# %%
print("your program start")
if my_age >= comparision_value :
    print("your are younge_age")
else:
    print("your are teen_age")
print("your program ends")
# Out:
# your program start
# your are younge_age
# your program ends

# %%
my_age=10

# %%
comparision_value=20

# %%
print("your program start")
if my_age <comparision_value:
    print("you are younge_age")
else:
    print("you are teen _age")
print("your program ends")
# Out:
# your program start
# you are younge_age
# your program ends

# %%
my_age=40

# %%
comparision_value=20

# %%
print("your program start")
if my_age >=comparision_value:
    print("you are teen_age")
else:
    print("you are younge_age")
print("your program ends")
# Out:
# your program start
# you are teen_age
# your program ends

# %%
weekday=['monday','tuesday','wednesday','thursday','friday']

# %%
weekend=['saturday','sunday']

# %%
weekday[0]
# Out:
# 'monday'

# %%
print("your program start")
if weekday:
          print("today is  weekday :",weekday[0])
else:
    print("today is weekend:",weekend)
print("your program ends")
# Out:
# your program start
# today is  weekday : monday
# your program ends

# %%
print("your program start")
if weekday:
          print("today is weekday :",weekday)
else: 
    print("today is weekend:",weekend)    
print("your program ends")
# Out:
# your program start
# today is weekday : ['monday', 'tuesday', 'wednesday', 'thursday', 'friday']
# your program ends

# %%
day="weekend"#weekday/weekend

# %%
weekday=['monday','tuesday','wednesday','thursday','friday']

# %%
weekend=['saturday','sunday']

# %%
print("your program start")
if day=="weekday":
    print("today is weekday:",weekday)
elif day=="weekend":
    print("today is weekend:",weekend)
print("your program ends")
# Out:
# your program start
# today is weekday: ['monday', 'tuesday', 'wednesday', 'thursday', 'friday']
# your program ends

# %%
print("your program start")
if day=="weekday":
    print("today is weekday:",weekday)
elif day=="weekend":
    print("today is weekend:",weekend)
print("your program ends")
# Out:
# your program start
# today is weekend: ['saturday', 'sunday']
# your program ends

# %%
Task_3:

# %%
# scenario1: today my business income 10 morethan print profit 
    otherwise print loss

# %%
original_value=10

# %%
comparision_value=10

# %%
if original_value>=comparision_value:
    print("your business is profit")
    print("congrats")
else:
    print("your business is loss")
    print("better luck next day")
# Out:
# your business is profit
# congrats

# %%
original_value=9
if original_value>=comparision_value:
    print("your business is profit")
    print("congrats")
else:
    print("your business is loss")
    print("better luck next day")
# Out:
# your business is loss
# better luck next day

# %%
original_value=12
if original_value>=comparision_value:
    print("your business is profit")
    
else:
    print("your business is loss")
    print("better luck next day")
# Out:
# your business is profit

# %%
scenario2:
# define the ages

# %%
your_age=28

# %%
sister_age=30

# %%
if your_age>sister_age:
    print("i am elder")
else:
    print("i am younger ")
# Out:
# i am younger

# %%
if your_age<sister_age:
    print("i am elder")
else:
    print("i am younger ")
# Out:
# i am elder

# %%
if your_age>=sister_age:
    print("i am elder")
else:
    print("i am younger ")
# Out:
# i am younger

# %%
sister_age=28
if your_age>=sister_age:
    print("i am elder")
else:
    print("i am younger ")
# Out:
# i am elder

# %%
#scenario3: festival offer in my shop

# %%
 purchase_amount=100

# %%
if purchase_amount  >= 100:
    print(" you got 30% discount")
elif purchase_amount <50:
    print("you got 10% discount")
else:
    print(" you got 20% discount")
# Out:
#  you got 30% discount

# %%
if purchase_amount  > 100:
    print(" you got 30% discount")
elif purchase_amount >50:
    print("you got 10% discount")
else:
    print(" you got 20% discount")
# Out:
# you got 10% discount

# %%
if purchase_amount  > 100:
    print(" you got 30% discount")
elif purchase_amount <50:
    print("you got 10% discount")
else:
    print(" you got 20% discount")
# Out:
#  you got 20% discount

# %%
# scenario4: movie theater prices

# %%
price=140#140/50/100

# %%
seat_type="balcony"#balcony/chair/bench

# %%
if price == 140:
    print(" your slected  seat type is:", seat_type)
    print("your  seat type movie price is:",price)
elif  price ==  50:
    print(" your slected seat type is:",seat_type)
    print("your seat type movie price is:",price)
elif price == 100:
    print("your  slected seat type is:",seat_type)
    print(" your  seat type movie price is:",price)
# Out:
#  your slected  seat type is: balcony
# your  seat type movie price is: 140

# %%
price=50#140/50/100

# %%
seat_type="chair"#balcony/chair/bench

# %%
if price == 140:
    print(" your slected  seat type is:", seat_type)
    print("your  seat type movie price is:",price)
elif  price ==  50:
    print(" your slected seat type is:",seat_type)
    print("your seat type movie price is:",price)
elif price == 100:
    print("your  slected seat type is:",seat_type)
    print(" your  seat type movie price is:",price)
# Out:
#  your slected seat type is: chair
# your seat type movie price is: 50

# %%
price=100#140/50/100

# %%
seat_type="bench"#balcony/chair/bench

# %%
if price == 140:
    print(" your slected  seat type is:", seat_type)
    print("your  seat type movie price is:",price)
elif  price ==  50:
    print(" your slected seat type is:",seat_type)
    print("your seat type movie price is:",price)
elif price == 100:
    print("your  slected seat type is:",seat_type)
    print(" your  seat type movie price is:",price)
# Out:
# your  slected seat type is: bench
#  your  seat type movie price is: 100

# %%
------------

# %%
# scenario 5: vehicle showroom classifier

# %%
#vehicle showroom ---2 types of vehiclies ----products
two wheeler vehicles---->bike,scooty
four wheeler vehicles---->car,lorry,van,jeep

# %%
# input varibles:

# %%
vehicle_type ="four wheeler" #two wheeler/four wheeler

# %%
if vehicle_type == "two wheeler":
    print("your vehicle type is :",vehicle_type)
    print("available two wheeler vehicle is  bike" )
    print("available two wheeler vehicle is scooty")
elif vehicle_type == "four wheeler":
    print("your vehicle type is :",vehicle_type)
    print("available four wheeler vehicle is  car" )
    print("available four wheeler vehicle is lorry")
    print("available four wheeler vehicle is van")
    print("available four wheeler vehicle is jeep")
else:
    print("the specific vehicle is not available")
# Out:
# your vehicle type is : four wheeler
# available four wheeler vehicle is  car
# available four wheeler vehicle is lorry
# available four wheeler vehicle is van
# available four wheeler vehicle is jeep

# %%
vehicle_type ="two wheeler" #two wheeler/four wheeler

# %%
if vehicle_type == "two wheeler":
    print("your vehicle type is :",vehicle_type)
    print("available two wheeler vehicle is  bike" )
    print("available two wheeler vehicle is scooty")
elif vehicle_type == "four wheeler":
    print("your vehicle type is :",vehicle_type)
    print("available four wheeler vehicle is  car" )
    print("available four wheeler vehicle is lorry")
    print("available four wheeler vehicle is van")
    print("available four wheeler vehicle is jeep")
else:
    print("the specific vehicle is not available")
# Out:
# your vehicle type is : two wheeler
# available two wheeler vehicle is  bike
# available two wheeler vehicle is scooty

# %%
vehicle_type ="three wheeler" #two wheeler/four wheeler

# %%
if vehicle_type == "two wheeler":
    print("your vehicle type is :",vehicle_type)
    print("available two wheeler vehicle is  bike" )
    print("available two wheeler vehicle is scooty")
elif vehicle_type == "four wheeler":
    print("your vehicle type is :",vehicle_type)
    print("available four wheeler vehicle is  car" )
    print("available four wheeler vehicle is lorry")
    print("available four wheeler vehicle is van")
    print("available four wheeler vehicle is jeep")
else:
    print("the specific vehicle is not available")
# Out:
# the specific vehicle is not available
