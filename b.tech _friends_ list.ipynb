# %%
8.friends names in list

# %%
friend_name=['meghana','spandana','prasanna','naveena','bhavana','bindu','ammu','reddy','subbu','dayakar']

# %%
friend_name
# Out:
# ['meghana',
#  'spandana',
#  'prasanna',
#  'naveena',
#  'bhavana',
#  'bindu',
#  'ammu',
#  'reddy',
#  'subbu',
#  'dayakar']

# %%
friend_name[0]
# Out:
# 'meghana'

# %%
friend_name[1]
# Out:
# 'spandana'

# %%
friend_name[2]
# Out:
# 'prasanna'

# %%
friend_name[3]
# Out:
# 'naveena'

# %%
friend_name[4]
# Out:
# 'bhavana'

# %%
friend_name[5]
# Out:
# 'bindu'

# %%
friend_name[6]
# Out:
# 'ammu'

# %%
friend_name[7]
# Out:
# 'reddy'

# %%
friend_name[8]
# Out:
# 'subbu'

# %%
friend_name[9]
# Out:
# 'dayakar'

# %%
friend_name[-1]
# Out:
# 'dayakar'

# %%
friend_name[-2]
# Out:
# 'subbu'

# %%
friend_name[-3]
# Out:
# 'reddy'

# %%
friend_name[-4]
# Out:
# 'ammu'

# %%
friend_name[-5]
# Out:
# 'bindu'

# %%
friend_name[-6]
# Out:
# 'bhavana'

# %%
friend_name[-7]
# Out:
# 'naveena'

# %%
friend_name[-8]
# Out:
# 'prasanna'

# %%
friend_name[-9]
# Out:
# 'spandana'

# %%
friend_name[0]
# Out:
# 'meghana'

# %%
friend_name[1:10]
# Out:
# ['spandana',
#  'prasanna',
#  'naveena',
#  'bhavana',
#  'bindu',
#  'ammu',
#  'reddy',
#  'subbu',
#  'dayakar']

# %%
friend_name[0:10]
# Out:
# ['meghana',
#  'spandana',
#  'prasanna',
#  'naveena',
#  'bhavana',
#  'bindu',
#  'ammu',
#  'reddy',
#  'subbu',
#  'dayakar']

# %%
friend_name[:10]
# Out:
# ['meghana',
#  'spandana',
#  'prasanna',
#  'naveena',
#  'bhavana',
#  'bindu',
#  'ammu',
#  'reddy',
#  'subbu',
#  'dayakar']

# %%
friend_name[1:10]
# Out:
# ['spandana',
#  'prasanna',
#  'naveena',
#  'bhavana',
#  'bindu',
#  'ammu',
#  'reddy',
#  'subbu',
#  'dayakar']

# %%
friend_name
# Out:
# ['meghana',
#  'spandana',
#  'prasanna',
#  'naveena',
#  'bhavana',
#  'bindu',
#  'ammu',
#  'reddy',
#  'subbu',
#  'dayakar']

# %%
friend_name[0:4]
# Out:
# ['meghana', 'spandana', 'prasanna', 'naveena']

# %%
friend_name[1:4]
# Out:
# ['spandana', 'prasanna', 'naveena']

# %%
friend_name[4:]
# Out:
# ['bhavana', 'bindu', 'ammu', 'reddy', 'subbu', 'dayakar']

# %%
friend_name[:5]
# Out:
# ['meghana', 'spandana', 'prasanna', 'naveena', 'bhavana']

# %%
friend_name[2:3]
# Out:
# ['prasanna']

# %%
friend_name[5:8]
# Out:
# ['bindu', 'ammu', 'reddy']
