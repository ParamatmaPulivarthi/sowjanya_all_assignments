# %%
1. create a friend_names.csv file delimiter(,)

# %%
import pandas as pd

# %%
df1_friends=pd.read_csv(r"C:\Users\hp\sowjanya_2026\friend_names.csv file.txt",sep=",")

# %%
df1_friends
# Out:
#   friendname      quality
# 0    meghana     creative
# 1     anusha         kind
# 2    naveena        funny
# 3  spandhana        smart
# 4   prasanna  hardworking
# 5     jhansi        loyal
# 6    bhavana       caring
# 7    dayakar      helpful
# 8      reddy       honest
# 9       ammu     friendly

# %%
df1_friends.shape
# Out:
# (10, 2)

# %%
df1_friends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   friendname  10 non-null     object
#  1   quality     10 non-null     object
# dtypes: object(2)
# memory usage: 292.0+ bytes

# %%
df1_friends.columns
# Out:
# Index(['friendname', 'quality'], dtype='object')

# %%
df1_friends.describe()
# Out:
#        friendname   quality
# count          10        10
# unique         10        10
# top       meghana  creative
# freq            1         1

# %%
df1_friends.head()
# Out:
#   friendname      quality
# 0    meghana     creative
# 1     anusha         kind
# 2    naveena        funny
# 3  spandhana        smart
# 4   prasanna  hardworking

# %%
2.create a family_members.txt file delimiter(*)

# %%
df2_family= pd.read_csv(r"C:\Users\hp\sowjanya_2026\family_members.txt file.txt",sep="*")

# %%
df2_family
# Out:
#    familymembername          relation
# 0          jayapaul            father
# 1     rangasarojini            mother
# 2        rajakumari      eldestsister
# 3  venkataramanayya   bigbrotherinlaw
# 4            mahima             niece
# 5         sunilraju           brother
# 6           meghana     sister_in_law
# 7       yonafrancis            nephew
# 8            salomi            sister
# 9         anilkumar           husband

# %%
df2_family.shape
# Out:
# (10, 2)

# %%
df2_family.columns
# Out:
# Index(['familymembername', 'relation'], dtype='object')

# %%
df2_family.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   familymembername  10 non-null     object
#  1   relation          10 non-null     object
# dtypes: object(2)
# memory usage: 292.0+ bytes

# %%
df2_family.describe()
# Out:
#        familymembername relation
# count                10       10
# unique               10       10
# top            jayapaul   father
# freq                  1        1

# %%
3.create a vegfood_items.txt file delimiter(|)

# %%
df3_veg=pd.read_csv(r"C:\Users\hp\sowjanya_2026\vegfood_items.txt file.txt",sep="|")

# %%
df3_veg
# Out:
#             vegfoodname     taste
# 0  paneer butter masala     spicy
# 1             dal tadka    savory
# 2          palak paneer      mild
# 3             aloo gobi     spicy
# 4           masala dosa     tangy
# 5     vegetable biryani  fragrant
# 6         chole bhature     spicy
# 7          Malaki kofta     sweet
# 8       gobi manchurian     spicy
# 9       mixed veg curry    savory

# %%
df3_veg.shape
# Out:
# (10, 2)

# %%
df3_veg.columns
# Out:
# Index(['vegfoodname', 'taste'], dtype='object')

# %%
df3_veg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   vegfoodname  10 non-null     object
#  1   taste        10 non-null     object
# dtypes: object(2)
# memory usage: 292.0+ bytes

# %%
df3_veg.describe()
# Out:
#                  vegfoodname  taste
# count                     10     10
# unique                    10      6
# top     paneer butter masala  spicy
# freq                       1      4

# %%
4.create a nonvegfood_items.txt file delimiter(|)

# %%
df4_nonveg=pd.read_csv(r"C:\Users\hp\sowjanya_2026\nonvegfood_items.txt file.txt",sep="|")

# %%
df4_nonveg
# Out:
#      nonvegfoodname    taste
# 0   chicken biryani    spicy
# 1          fish fry   crispy
# 2      mutton curry     rich
# 3    butter chicken   creamy
# 4         egg roast    tangy
# 5      prawn masala   savory
# 6      grilled fish    smoky
# 7        chicken 65      hot
# 8       keema matar    spicy
# 9  tandoori chicken  charred

# %%
df4_nonveg.shape
# Out:
# (10, 2)

# %%
df4_nonveg.columns
# Out:
# Index(['nonvegfoodname', 'taste'], dtype='object')

# %%
df4_nonveg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   nonvegfoodname  10 non-null     object
#  1   taste           10 non-null     object
# dtypes: object(2)
# memory usage: 292.0+ bytes

# %%
df4_nonveg.describe()
# Out:
#          nonvegfoodname  taste
# count                10     10
# unique               10      9
# top     chicken biryani  spicy
# freq                  1      2

# %%
5.create a month_names.txt file delimiter(&)

# %%
df5_month=pd.read_csv(r"C:\Users\hp\sowjanya_2026\month_names.txt file.txt",sep="&")

# %%
df5_month
# Out:
#    monthname      season
# 0    january      winter
# 1   february      winter
# 2      march      spring
# 3      april      spring
# 4        may      summer
# 5       june      summer
# 6       july     monsoon
# 7     august     monsoon
# 8   septmber      autumn
# 9    October      autumn
# 10  november  pre-winter
# 11  december      winter

# %%
df5_month.shape
# Out:
# (12, 2)

# %%
df5_month.columns
# Out:
# Index(['monthname', 'season'], dtype='object')

# %%
df5_month.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   monthname  12 non-null     object
#  1   season     12 non-null     object
# dtypes: object(2)
# memory usage: 324.0+ bytes

# %%
df5_month.describe()
# Out:
#        monthname  season
# count         12      12
# unique        12       6
# top      january  winter
# freq           1       3

# %%
6. create a colours_names.txt file delimiter(^)

# %%
df6_colours=pd.read_csv(r"C:\Users\hp\sowjanya_2026\colours_names.txt file.txt",sep="^")

# %%
df6_colours
# Out:
#    colourname_in_english colourname_in_hindi colourname_in_telugu
# 0                    red                 lal                erupu
# 1                   blue               neela               neelam
# 2                  green                hara            akupachha
# 3                 yellow               peela               pasupu
# 4                  white               safed               telupu
# 5                  black                kala              nallapu
# 6                   pink              gulabi               gulabi
# 7                 orange             narangi              narangi
# 8                  brown               bhura              godhuma
# 9                   grey              sileti             boodidha
# 10                purple            baingani              vankaya
# 11                  gold             sunehra              bangaru

# %%
df6_colours.shape
# Out:
# (12, 3)

# %%
df6_colours.columns
# Out:
# Index(['colourname_in_english', 'colourname_in_hindi', 'colourname_in_telugu'], dtype='object')

# %%
df6_colours.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   colourname_in_english  12 non-null     object
#  1   colourname_in_hindi    12 non-null     object
#  2   colourname_in_telugu   12 non-null     object
# dtypes: object(3)
# memory usage: 420.0+ bytes

# %%
df6_colours.describe()
# Out:
#        colourname_in_english colourname_in_hindi colourname_in_telugu
# count                     12                  12                   12
# unique                    12                  12                   12
# top                      red                 lal                erupu
# freq                       1                   1                    1

# %%
7.create a friend_names.xls file

# %%
df7_friends=pd.read_excel(r"C:\Users\hp\sowjanya_2026\friend_names.xls file.xlsx")

# %%
df7_friends
# Out:
#   FriendName      Quality
# 0    meghana     creative
# 1     anusha         kind
# 2    naveena        funny
# 3  spandhana        smart
# 4   prasanna  hardworhing
# 5     jhansi        loyal
# 6    bhavana       caring
# 7    dayakar      helpful
# 8      reddy       honest
# 9       ammu     friendly

# %%
basic checks:

# %%
df7_friends.shape
# Out:
# (10, 2)

# %%
df7_friends.columns
# Out:
# Index(['FriendName', 'Quality'], dtype='object')

# %%
df7_friends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FriendName  10 non-null     object
#  1   Quality     10 non-null     object
# dtypes: object(2)
# memory usage: 292.0+ bytes

# %%
df7_friends.describe()
# Out:
#        FriendName   Quality
# count          10        10
# unique         10        10
# top       meghana  creative
# freq            1         1

# %%
8. create a family_mebers.xls file

# %%
df8_family=pd.read_excel(r"C:\Users\hp\sowjanya_2026\family_members.xls file.xlsx")

# %%
df8_family
# Out:
#   FamilyMemberName     Relation
# 0         jayapaul       father
# 1    rangasarojini       mother
# 2       rajakumari  eldersister
# 3    venkataramana  brotherilla
# 4           mahima        niece
# 5        sunilraju      brother
# 6          meghana   sisterilla
# 7             yona       nephew
# 8           salomi       sister
# 9        anilkumar      husband

# %%
df8_family.shape
# Out:
# (10, 2)

# %%
df8_family.columns
# Out:
# Index(['FamilyMemberName', 'Relation'], dtype='object')

# %%
df8_family.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FamilyMemberName  10 non-null     object
#  1   Relation          10 non-null     object
# dtypes: object(2)
# memory usage: 292.0+ bytes

# %%
df8_family.describe()
# Out:
#        FamilyMemberName Relation
# count                10       10
# unique               10       10
# top            jayapaul   father
# freq                  1        1

# %%
9. create a vegfood_items.xlsx file

# %%
df9_veg=pd.read_excel(r"C:\Users\hp\sowjanya_2026\Vegfood_items.xlsx file.xlsx")

# %%
df9_veg
# Out:
#             VegFoodName     Taste
# 0  paneer butter masala     spicy
# 1             dal tadka    savory
# 2          palak panner      mild
# 3             aolo gobi     spicy
# 4           masala dosa     tangy
# 5     vegetable biryani  fragrant
# 6         chole bhature     spicy
# 7          malaki kofta     sweet
# 8      gobi manchuriyan     spicy
# 9       mixed veg curry    savory

# %%
df9_veg.shape
# Out:
# (10, 2)

# %%
df9_veg.columns
# Out:
# Index(['VegFoodName', 'Taste'], dtype='object')

# %%
df9_veg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   VegFoodName  10 non-null     object
#  1   Taste        10 non-null     object
# dtypes: object(2)
# memory usage: 292.0+ bytes

# %%
df9_veg.describe()
# Out:
#                  VegFoodName  Taste
# count                     10     10
# unique                    10      6
# top     paneer butter masala  spicy
# freq                       1      4

# %%
10.create a nonvegfood_items.xlsx file

# %%
df10_nonveg=pd.read_excel(r"C:\Users\hp\sowjanya_2026\NonVegfood_items.xlsx file.xlsx")

# %%
df10_nonveg
# Out:
#      NonVegFoodName    Taste
# 0   chicken biryani    spicy
# 1           fishfry   crispy
# 2     mutton curryy     rich
# 3    butter chicken    cremy
# 4         egg roast    tangy
# 5      prawn masala   savory
# 6      grilled fish    smoky
# 7        chicken 65      hot
# 8       keema matar    spicy
# 9  tandoori chicken  charred

# %%
df10_nonveg.shape
# Out:
# (10, 2)

# %%
df10_nonveg.columns
# Out:
# Index(['NonVegFoodName', 'Taste'], dtype='object')

# %%
df10_nonveg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NonVegFoodName  10 non-null     object
#  1   Taste           10 non-null     object
# dtypes: object(2)
# memory usage: 292.0+ bytes

# %%
df10_nonveg.describe()
# Out:
#          NonVegFoodName  Taste
# count                10     10
# unique               10      9
# top     chicken biryani  spicy
# freq                  1      2

# %%
11. create a month_names.xlsx file

# %%
df11_month=pd.read_excel(r"C:\Users\hp\sowjanya_2026\month_names.xlsx file.xlsx")

# %%
df11_month
# Out:
#    MonthName    Season
# 0    january    winter
# 1   february    winter
# 2      march    spring
# 3      april    spring
# 4        may    summer
# 5       june    summer
# 6       july  moonsoon
# 7     august  moonsoon
# 8   septmber    autumn
# 9    October    autumn
# 10  november    winter
# 11  december    winter

# %%
df11_month.shape
# Out:
# (12, 2)

# %%
df11_month.columns
# Out:
# Index(['MonthName', 'Season'], dtype='object')

# %%
df11_month.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MonthName  12 non-null     object
#  1   Season     12 non-null     object
# dtypes: object(2)
# memory usage: 324.0+ bytes

# %%
df11_month.describe()
# Out:
#        MonthName  Season
# count         12      12
# unique        12       5
# top      january  winter
# freq           1       4

# %%
12. create a colours_names.xlsx file

# %%
df12_colours=pd.read_excel(r"C:\Users\hp\sowjanya_2026\colours_names.xlsx file.xlsx")

# %%
df12_colours
# Out:
#    colourName_in_English colourName_in_Hindhi colourName_in_Teluhu
# 0                    red                  lal                erupu
# 1                   blue                neela               neelam
# 2                  green                 hara            akupachha
# 3                 yellow                peela               pasupu
# 4                  white                safed               telupu
# 5                  black                 kala              nallapu
# 6                   pink               gulabi               gulabi
# 7                 orange              narangi              narangi
# 8                  brown                bhura              godhuma
# 9                   grey               sileti             boodidha
# 10                purple             baingani              vankaya
# 11                  gold              sunehra              bangaru

# %%
df12_colours.shape
# Out:
# (12, 3)

# %%
df12_colours.columns
# Out:
# Index(['colourName_in_English', 'colourName_in_Hindhi',
#        'colourName_in_Teluhu'],
#       dtype='object')

# %%
df12_colours.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   colourName_in_English  12 non-null     object
#  1   colourName_in_Hindhi   12 non-null     object
#  2   colourName_in_Teluhu   12 non-null     object
# dtypes: object(3)
# memory usage: 420.0+ bytes

# %%
df12_colours.describe()
# Out:
#        colourName_in_English colourName_in_Hindhi colourName_in_Teluhu
# count                     12                   12                   12
# unique                    12                   12                   12
# top                      red                  lal                erupu
# freq                       1                    1                    1
