# %%
4.create dict with your family members and relations.

# %%
# hi this is a program

# %%
family_members_relations={
    "family_members":["jayapaul",
                     "rangasarojini",
                     "rajakumari",
                     "sunilraju",
                     "meghana",
                     "salomi",
                     "venkataramana",
                     "venketeswarao",
                     "anilkumar",
                     "sowjanya"
                     ],
                     "relations":[
                         "father",
                         "mother",
                         "eldersister",
                         "brother",
                         "sisterilla",
                         "sister",
                         "brotherilla",
                         "maternaluncle",
                         "myhusband",
                         "myself"
                         
                           ]      
    
    
}

# %%
dict_family_members_relations
# Out:
# {'family_members': ['jayapaul',
#   'rangasarojini',
#   'rajakumari',
#   'sunilraju',
#   'meghana',
#   'salomi',
#   'venkataramana',
#   'venketeswarao',
#   'anilkumar',
#   'sowjanya'],
#  'relations': ['father',
#   'mother',
#   'eldersister',
#   'brother',
#   'sisterilla',
#   'sister',
#   'brotherilla',
#   'maternaluncle',
#   'myhusband',
#   'myself']}

# %%
print(dict_family_members_relations)
# Out:
# {'family_members': ['jayapaul', 'rangasarojini', 'rajakumari', 'sunilraju', 'meghana', 'salomi', 'venkataramana', 'venketeswarao', 'anilkumar', 'sowjanya'], 'relations': ['father', 'mother', 'eldersister', 'brother', 'sisterilla', 'sister', 'brotherilla', 'maternaluncle', 'myhusband', 'myself']}

# %%
dict_family_members_relations.keys()
# Out:
# dict_keys(['family_members', 'relations'])

# %%
dict_family_members_relations["family_members"]
# Out:
# ['jayapaul',
#  'rangasarojini',
#  'rajakumari',
#  'sunilraju',
#  'meghana',
#  'salomi',
#  'venkataramana',
#  'venketeswarao',
#  'anilkumar',
#  'sowjanya']

# %%
dict_family_members_relations["family_members"][0]
# Out:
# 'jayapaul'

# %%
print("my favourite family member name is",dict_family_members_relations["family_members"][0])
# Out:
# my favourite family member name is jayapaul

# %%
dict_family_members_relations["relations"]
# Out:
# ['father',
#  'mother',
#  'eldersister',
#  'brother',
#  'sisterilla',
#  'sister',
#  'brotherilla',
#  'maternaluncle',
#  'myhusband',
#  'myself']

# %%
dict_family_members_relations["relations"][3]
# Out:
# 'brother'

# %%
print("my favourite family member name  is",  dict_family_members_relations["relations"][3],dict_family_members_relations["family_members"][3])
# Out:
# my favourite family member name  is brother sunilraju

# %%
print("my father name is",dict_family_members_relations["family_members"][0])
# Out:
# my father name is jayapaul
