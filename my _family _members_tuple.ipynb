# %%
9.create a tuple (family_members) with your family members.

# %%
family_members=("jayapaul-father","ranga_mother","rajakumari_eldersister","mahima_niece","sunilraju_brother","meghana_sisterilla","yona-nephew","sister_salomi","myself_sowjanya","myhusband_anil")

# %%
family_members
# Out:
# ('jayapaul-father',
#  'ranga_mother',
#  'rajakumari_eldersister',
#  'mahima_niece',
#  'sunilraju_brother',
#  'meghana_sisterilla',
#  'yona-nephew',
#  'sister_salomi',
#  'myself_sowjanya',
#  'myhusband_anil')

# %%
print(family_members)
# Out:
# ('jayapaul-father', 'ranga_mother', 'rajakumari_eldersister', 'mahima_niece', 'sunilraju_brother', 'meghana_sisterilla', 'yona-nephew', 'sister_salomi', 'myself_sowjanya', 'myhusband_anil')

# %%
family_members[0]
# Out:
# 'jayapaul-father'

# %%
family_members[1]
# Out:
# 'ranga_mother'

# %%
family_members[2]
# Out:
# 'rajakumari_eldersister'

# %%
family_members[3]
# Out:
# 'mahima_niece'

# %%
family_members[4]
# Out:
# 'sunilraju_brother'

# %%
family_members[5]
# Out:
# 'meghana_sisterilla'

# %%
family_members[6]
# Out:
# 'yona-nephew'

# %%
family_members[7]
# Out:
# 'sister_salomi'

# %%
family_members[8]
# Out:
# 'myself_sowjanya'

# %%
family_members[9]
# Out:
# 'myhusband_anil'

# %%
family_members[-1]
# Out:
# 'myhusband_anil'

# %%
family_members[-2]
# Out:
# 'myself_sowjanya'

# %%
family_members[-3]
# Out:
# 'sister_salomi'

# %%
family_members[-4]
# Out:
# 'yona-nephew'

# %%
family_members[-5]
# Out:
# 'meghana_sisterilla'

# %%
family_members[-6]
# Out:
# 'sunilraju_brother'

# %%
family_members[-7]
# Out:
# 'mahima_niece'

# %%
family_members[-8]
# Out:
# 'rajakumari_eldersister'

# %%
family_members[-9]
# Out:
# 'ranga_mother'

# %%
family_members[0]
# Out:
# 'jayapaul-father'

# %%
family_members[3:5]
# Out:
# ('mahima_niece', 'sunilraju_brother')

# %%
family_members[-4:]
# Out:
# ('yona-nephew', 'sister_salomi', 'myself_sowjanya', 'myhusband_anil')

# %%
family_members[2:3]
# Out:
# ('rajakumari_eldersister',)

# %%
family_members[-4:-2]
# Out:
# ('yona-nephew', 'sister_salomi')

# %%
family_members[:-3]
# Out:
# ('jayapaul-father',
#  'ranga_mother',
#  'rajakumari_eldersister',
#  'mahima_niece',
#  'sunilraju_brother',
#  'meghana_sisterilla',
#  'yona-nephew')
