# %%
task:6

# %%
#  friend names in loop

# %%
# friend names list

# %%
friend_names=["meghana","spandhana","prasanna","jhansi","anusha","sandhya","supraja","nandhini","bhavana","harikha"]

# %%
for change_value in friend_names:
    print("my friend name is ",change_value)
# Out:
# my friend name is  meghana
# my friend name is  spandhana
# my friend name is  prasanna
# my friend name is  jhansi
# my friend name is  anusha
# my friend name is  sandhya
# my friend name is  supraja
# my friend name is  nandhini
# my friend name is  bhavana
# my friend name is  harikha

# %%
task:7

# %%
# family members names in loop

# %%
family_members=['jayapaul','rangasarojini','rajakumari','sunilraju','salomi','meghana','yona','mahima','sowjanya','anil']

# %%
for change_value in family_members:
    print("my family member name is",change_value)
# Out:
# my family member name is jayapaul
# my family member name is rangasarojini
# my family member name is rajakumari
# my family member name is sunilraju
# my family member name is salomi
# my family member name is meghana
# my family member name is yona
# my family member name is mahima
# my family member name is sowjanya
# my family member name is anil

# %%
task:8

# %%
# a list of food names in loop:

# %%
food_names=["paneertikka","coconut rice"," dal makhani","potatao fry","lemon rice","parota","lady fingers fry","veg biryani","idli sambar"," palak panner"]

# %%
for change_value in food_names:
    print("my favourite  food item name is ",change_value)
# Out:
# my favourite  food item name is  paneertikka
# my favourite  food item name is  coconut rice
# my favourite  food item name is   dal makhani
# my favourite  food item name is  potatao fry
# my favourite  food item name is  lemon rice
# my favourite  food item name is  parota
# my favourite  food item name is  lady fingers fry
# my favourite  food item name is  veg biryani
# my favourite  food item name is  idli sambar
# my favourite  food item name is   palak panner

# %%
task:9

# %%
#  a tuple food names in loop:

# %%
food_names=("chicken biryani","fish fry","fish curry","crab curry","mutton keema","butter chicken","prawn curry","egg curry","mutton curry","chickencurry")

# %%
for change_value in food_names:
    print("my favourite  nonveg food item name is",change_value)
# Out:
# my favourite  nonveg food item name is chicken biryani
# my favourite  nonveg food item name is fish fry
# my favourite  nonveg food item name is fish curry
# my favourite  nonveg food item name is crab curry
# my favourite  nonveg food item name is mutton keema
# my favourite  nonveg food item name is butter chicken
# my favourite  nonveg food item name is prawn curry
# my favourite  nonveg food item name is egg curry
# my favourite  nonveg food item name is mutton curry
# my favourite  nonveg food item name is chickencurry

# %%
task:10

# %%
# a set colours  names in loop

# %%
colour_names={"red","blue","green","yellow","orange","purple","pink","black","white","brown"}

# %%
# colour names using in loop

# %%
for change_value in colour_names:
    print("the colour name is",change_value)
# Out:
# the colour name is yellow
# the colour name is white
# the colour name is green
# the colour name is red
# the colour name is blue
# the colour name is pink
# the colour name is black
# the colour name is brown
# the colour name is purple
# the colour name is orange

# %%
task:11

# %%
# alist of month names in loop:

# %%
month_names=['january','february','march','april','may','june','july','august','septmber','october']

# %%
for change_value in month_names:
    print("this month name is",change_value)
# Out:
# this month name is january
# this month name is february
# this month name is march
# this month name is april
# this month name is may
# this month name is june
# this month name is july
# this month name is august
# this month name is septmber
# this month name is october

# %%
task:12

# %%
print 9th table(1 to 90)

# %%
print("9th table:")
for i in range(1,11):
    result = 9 * i
    print(f"9  * {i} = {result}" )
# Out:
# 9th table:
# 9  * 1 = 9
# 9  * 2 = 18
# 9  * 3 = 27
# 9  * 4 = 36
# 9  * 5 = 45
# 9  * 6 = 54
# 9  * 7 = 63
# 9  * 8 = 72
# 9  * 9 = 81
# 9  * 10 = 90

# %%
task:13

# %%
print 12th table(1 to 20)

# %%
print("12th table:")
for i in  range(1, 11):
    result = 12 * i
    print(f"12 * {i} = {result}" )
# Out:
# 12th table:
# 12 * 1 = 12
# 12 * 2 = 24
# 12 * 3 = 36
# 12 * 4 = 48
# 12 * 5 = 60
# 12 * 6 = 72
# 12 * 7 = 84
# 12 * 8 = 96
# 12 * 9 = 108
# 12 * 10 = 120
