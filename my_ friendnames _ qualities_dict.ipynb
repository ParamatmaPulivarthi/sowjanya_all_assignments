# %%
5:create friend names and their quality.

# %%
friends_data = {
    "friend_names":["meghanaa","spandana","prasanna","naveena","subbu","reddy","subbu","dayakar","ammu","bhavana"]
                
                
                
                ,"quality":["intelligent","kind","talk active","funny","understanding","loyalty","honesty","forgiveness","helpfulness","caring"]}

# %%
print(friends_data)
# Out:
# {'friend_names': ['meghanaa', 'spandana', 'prasanna', 'naveena', 'subbu', 'reddy', 'subbu', 'dayakar', 'ammu', 'bhavana'], 'quality': ['intelligent', 'kind', 'talk active', 'funny', 'understanding', 'loyalty', 'honesty', 'forgiveness', 'helpfulness', 'caring']}

# %%
print("my intelligent friend name is",intelligentfriend_name_v1)
# Out:
# my intelligent friend name is meghana

# %%
friends_data.keys()
# Out:
# dict_keys(['friend_names', 'quality'])

# %%
friends_data["friend_names"]
# Out:
# ['meghanaa',
#  'spandana',
#  'prasanna',
#  'naveena',
#  'subbu',
#  'reddy',
#  'subbu',
#  'dayakar',
#  'ammu',
#  'bhavana']

# %%
friends_data["friend_names"][0]
# Out:
# 'meghanaa'

# %%
friends_data["quality"]
# Out:
# ['intelligent',
#  'kind',
#  'talk active',
#  'funny',
#  'understanding',
#  'loyalty',
#  'honesty',
#  'forgiveness',
#  'helpfulness',
#  'caring']

# %%
friends_data["quality"][0]
# Out:
# 'intelligent'

# %%
print("the intelligent friend name is",friends_data["friend_names"][0])
# Out:
# the intelligent friend name is meghanaa

# %%
print("my best friend name is",friends_data["friend_names"][0])
# Out:
# my best friend name is meghanaa
